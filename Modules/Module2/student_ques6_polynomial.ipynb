# %% [markdown]
# # Calculating Gravity

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

import os
os.chdir("/content/drive/My Drive/AIMOOC")
# !ls

import pandas as pd
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
# Out:
# Mounted at /content/drive/
# Modules  Staff

# %%
df = pd.read_csv("/content/drive/My Drive/AIMOOC/Modules/Module2/Data/planets.csv")
df

# %%
# your code here to find the quadratic relationship between time and planet_1

# %%
# your code here to find the quadratic relationship between time and planet_2

# %%
# your code here to find the quadratic relationship between time and planet_3

# %%
# your code here to find the quadratic relationship between time and planet_4

# %%
# your code here to find the quadratic relationship between time and planet_5

# %%
# your code here to find the quadratic relationship between time and planet_6

# %%
# your code here to find the quadratic relationship between time and planet_7

# %% [markdown]
# Drag the three planet data columns that correspond to Mars, Saturn, and Jupiter.
