# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>What is Colaboratory?</h1>
#
# Colaboratory, or "Colab" for short, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to GPUs
# - Easy sharing
#
# Whether you are a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier.

# %% [markdown]
# ## Cells
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.

# %% [markdown]
# ## Text cells
# This is a text cell. You can **double-click** to edit this cell. Text cells
# use markdown syntax. To learn more, see our [markdown
# guide](/notebooks/markdown_guide.ipynb).

# %% [markdown]
# ## Code cells
# Below is a **code cell**. Once the toolbar button indicates CONNECTED, click in the cell to select it and execute the contents in the following ways:
#
# * Click the **Play icon** in the left gutter of the cell;
# * Type **Cmd/Ctrl+Enter** to run the cell in place;
# * Type **Shift+Enter** to run the cell and move focus to the next cell (adding one if none exists); or
# * Type **Alt+Enter** to run the cell and insert a new code cell immediately below it.
#
# There are additional options for running some or all cells in the **Runtime** menu.

# %% [markdown]
# You can only run the next cell if you ran the previous one. Otherwise, it won't know what the value of `a` is. Be sure you ran the cell by hitting the Play icon or typing Cmd/Ctrl+Enter.

# %%
b = a + 3
b

# %% [markdown]
# Python does not solve equations for you! This line takes the thing to the right-hand-side of the equal sign and saves it with the variable name to the left-hand-side of the equal sign.

# %%
a = a + 1
a
# Out:
# 11

# %% [markdown]
# Try running the above code cell a few times to see how the value of `a` changes.

# %% [markdown]
# ## Order of Execution
#
# Every time you run one of your code cells, it updates the number in square brackets to keep track of the order in which cells were executed. (If you don't see a number in the square brackets, you may need to move your mouse off the cell.)
#
# For example, if you now go back and re-run
#
# `b = a + 3`
#
# the value of `a` does not come from the cell above. It comes from the last value assigned to `a` in the cells that you ran most recently. At this point, `a` has been incremented to 11 (or more if you ran the cell `a = a + 1` multiple times. Running the cell `b = a + 3` will add 3 to your latest value of `a`.
#
# Also note that the number that now shows up by the `b = a + 3` cell is larger than the one below in the `a = a + 1`. This indicates that this cell was executed more recently than the one below.

# %% [markdown]
# ## Adding and moving cells
# You can add new cells by using the **+ CODE** and **+ TEXT** buttons that show when you hover between cells. These buttons are also in the toolbar above the notebook where they can be used to add a cell below the currently selected cell.
#
# You can move a cell by selecting it and clicking **Cell Up** or **Cell Down** in the top toolbar.
#
# Consecutive cells can be selected by "lasso selection" by dragging from outside one cell and through the group.  Non-adjacent cells can be selected concurrently by clicking one and then holding down Ctrl while clicking another.  Similarly, using Shift instead of Ctrl will select all intermediate cells.

# %% [markdown]
# ## Happy Coding!
# You can now use this notebook to add more code cells and play around with various commands.

# %% [markdown]
# Try to perform these computations in the code cell below.
#
# * Use Colab to compute `13*3`
# * Use Colab to compute `57*23`
#
# Note that the <font color="green">`# Your code here`</font> is a comment. A comment is a line that is ignored when running a code cell. Any line that begins with a <font color="green">`#`</font> is treated as a comment in your code. You can type your code in the line that follows the comment, and the cell will behave the same way as if you deleted the comment from the code cell.

# %%
# Your code here

# %% [markdown]
# Try to perform these computations in the code cell below.
#
# * Set variable `a` to be `13 * 3`.
# * Then type `a` for it to print out the value of `a`.

# %% [markdown]
# Hopefully, you have not yet run into any coding errors, however, a very common python coding error that you should be aware is caused by the use of white space. Suppose that in the code cell above, your first line of code was `a = 13 * 3`, and your second line of code was `    a`. Note that the second line contains some leading white space characters before the `a`. In python, indentation provides context about how to interpret your code. Thus, if you add unnecessary white space in your code and try to run the code cell, python will return an `IndentationError` message. If you remove, the white space before the `a` and try to rerun the cell, the error will go away. Keep this in mind as you proceed with your coding exercises throughout this course.

# %%
# Your code here

# %% [markdown]
# Try to perform these computations.
#
# * Create a new Colab "Code" cell below
# * Set variable `b` to `7` and variable `c` to `a + b`.
# * Show the result of `c`.

# %% [markdown]
# Now add a Colab "Code" cell that sets `a` to `2`. Set `c` to be `a+b`. Show the value of `c`.

# %%
# Your code here
